# %% [markdown]
# # Importing the Data
#
# - Import relevant imdb files for movie/actor data

# %%
import pandas as pd

# %%
#name of people on titles. known_for_titles matches the title_id
imdb_name = pd.read_csv('zippedData/imdb.name.basics.csv.gz') 

#title, region, language
imdb_title_a =  pd.read_csv('zippedData/imdb.title.akas.csv.gz') 

#title, year, runtime, genre
imdb_title_b =  pd.read_csv('zippedData/imdb.title.basics.csv.gz') 

#categorizes the people(nameid) on the movie(titleid) and includes their job role and characters they played
imdb_title_p = pd.read_csv('zippedData/imdb.title.principals.csv.gz')

# %% [markdown]
# # Movie Data
# - Merge IMDB dataframes related to just movies
# - Specify movies released in the US
# - Drop unnecessary columns and duplicate values
# - Import movie data from API calls
# - Create functions to pull out values from nested data
# - Create new columns for genre, season, rating, and profitability
# - Remove null and 0 values

# %%
#renamed the 'tconst' column to match the title_id column from imdb_title_a for merging 
imdb_title_b = imdb_title_b.rename(columns = {"tconst": "title_id"})

# %%
#merge b and a df's first to just get all of the title info and the region in one table

title_ba = imdb_title_b.merge(imdb_title_a, on = 'title_id', how = 'left')
title_ba.head()
# Out:
#     title_id primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 1  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 2  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 3  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 4  tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                genres  ordering      title region language     types  \
# 0  Action,Crime,Drama       1.0  Sangharsh     IN       hi       NaN
# 1  Action,Crime,Drama       2.0  Sunghursh    NaN      NaN  original
# 2  Action,Crime,Drama       3.0  Sunghursh     IN      NaN       NaN
# 3  Action,Crime,Drama       4.0  Sunghursh     IN       hi       NaN
# 4  Action,Crime,Drama       5.0  Sungharsh     IN       hi       NaN
#
#                     attributes  is_original_title
# 0  alternative transliteration                0.0
# 1                          NaN                1.0
# 2                          NaN                0.0
# 3  alternative transliteration                0.0
# 4         alternative spelling                0.0

# %%
#get US movies
us_titles = title_ba.groupby('region').get_group('US')
us_titles.head()
# Out:
#      title_id                       primary_title  \
# 14  tt0069049          The Other Side of the Wind
# 31  tt0112502                             Bigfoot
# 52  tt0159369  Cooper and Hemingway: The True Gen
# 63  tt0192528                       Heaven & Hell
# 65  tt0230212                   The Final Journey
#
#                         original_title  start_year  runtime_minutes  \
# 14          The Other Side of the Wind        2018            122.0
# 31                             Bigfoot        2017              NaN
# 52  Cooper and Hemingway: The True Gen        2013            180.0
# 63                      Reverse Heaven        2018            104.0
# 65                   The Final Journey        2010            120.0
#
#              genres  ordering                               title region  \
# 14            Drama       2.0          The Other Side of the Wind     US
# 31  Horror,Thriller       1.0                             Bigfoot     US
# 52      Documentary       3.0  Cooper and Hemingway: The True Gen     US
# 63            Drama       1.0                       Heaven & Hell     US
# 65            Drama       1.0                   The Final Journey     US
#
#    language        types attributes  is_original_title
# 14      NaN  imdbDisplay        NaN                0.0
# 31      NaN          NaN        NaN                0.0
# 52      NaN          NaN        NaN                0.0
# 63      NaN  imdbDisplay        NaN                0.0
# 65      NaN          NaN        NaN                0.0

# %%
#drop any columns we don't need
clean_us_movies = us_titles.drop(columns = ['primary_title', 'original_title', 'runtime_minutes', 'start_year','language', 'types', 'attributes', 'is_original_title'])
#drop duplicates that have the same title_id AND title
clean_us_movies = clean_us_movies.drop_duplicates(subset=(['title_id', 'title']), keep="first")

# %%
#drop any remaining duplicates that just have the same title_id
clean_us_movies = clean_us_movies.drop_duplicates(subset=('title_id'), keep="first")

# %%
#export clean_us_movies to use title_id's for API calls

#clean_us_movies.to_csv('clean_us_moves.csv', index=False)

# %%
#import us movie data df that now includes API movie data

#budget, genres, release date, revenue, title, ratings
movie_data = pd.read_csv('./movie_data.csv')

# %%
#drop columns from movie_data
movie_data = movie_data.drop(columns = ['Unnamed: 0', 'original_language', 'original_title', 'production_companies'])
movie_data.head()
# Out:
#        budget                                             genres        id  \
# 0  12000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  299782.0
# 1         0.0                [{'id': 99, 'name': 'Documentary'}]  224332.0
# 2   5000000.0                      [{'id': 18, 'name': 'Drama'}]  567662.0
# 3  65000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...  116977.0
# 4   2000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  323498.0
#
#      imdb_id release_date  revenue                               title  \
# 0  tt0069049   2018-11-02      0.0          The Other Side of the Wind
# 1  tt0159369   2013-09-27      0.0  Cooper and Hemingway: The True Gen
# 2  tt0192528   2018-11-06      0.0                       Heaven & Hell
# 3  tt0249516   2012-06-15  73706.0                          Foodfight!
# 4  tt0255820   2013-08-11      0.0                   Return to Babylon
#
#                                              results
# 0  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 1  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 2  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 3  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 4  [{'iso_3166_1': 'US', 'release_dates': [{'cert...

# %%
#convert genres string to a list for later manipulation
for name in range(len(movie_data.genres)):
    movie_data.genres[name] = eval(movie_data.genres[name])
movie_data.head()
# Out:
# /Users/danielmocombe/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        budget                                             genres        id  \
# 0  12000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  299782.0
# 1         0.0                [{'id': 99, 'name': 'Documentary'}]  224332.0
# 2   5000000.0                      [{'id': 18, 'name': 'Drama'}]  567662.0
# 3  65000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...  116977.0
# 4   2000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  323498.0
#
#      imdb_id release_date  revenue                               title  \
# 0  tt0069049   2018-11-02      0.0          The Other Side of the Wind
# 1  tt0159369   2013-09-27      0.0  Cooper and Hemingway: The True Gen
# 2  tt0192528   2018-11-06      0.0                       Heaven & Hell
# 3  tt0249516   2012-06-15  73706.0                          Foodfight!
# 4  tt0255820   2013-08-11      0.0                   Return to Babylon
#
#                                              results
# 0  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 1  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 2  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 3  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 4  [{'iso_3166_1': 'US', 'release_dates': [{'cert...

# %%
#convert results from string to list for later manipulation
for name in range(len(movie_data.results)):
    movie_data.results[name] = eval(movie_data.results[name])
movie_data.head()
# Out:
# /Users/danielmocombe/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        budget                                             genres        id  \
# 0  12000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  299782.0
# 1         0.0                [{'id': 99, 'name': 'Documentary'}]  224332.0
# 2   5000000.0                      [{'id': 18, 'name': 'Drama'}]  567662.0
# 3  65000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...  116977.0
# 4   2000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  323498.0
#
#      imdb_id release_date  revenue                               title  \
# 0  tt0069049   2018-11-02      0.0          The Other Side of the Wind
# 1  tt0159369   2013-09-27      0.0  Cooper and Hemingway: The True Gen
# 2  tt0192528   2018-11-06      0.0                       Heaven & Hell
# 3  tt0249516   2012-06-15  73706.0                          Foodfight!
# 4  tt0255820   2013-08-11      0.0                   Return to Babylon
#
#                                              results
# 0  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 1  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 2  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 3  [{'iso_3166_1': 'US', 'release_dates': [{'cert...
# 4  [{'iso_3166_1': 'US', 'release_dates': [{'cert...

# %%
#convert release date from string to datetime type
movie_data['release_date'] = pd.to_datetime(movie_data['release_date'])

# %%
#create a column for the month
movie_data['month'] = pd.DatetimeIndex(movie_data['release_date']).month

# %%
#create a column for the year
movie_data['year'] = pd.DatetimeIndex(movie_data['release_date']).year
movie_data.head()
# Out:
#        budget                                             genres        id  \
# 0  12000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  299782.0
# 1         0.0                [{'id': 99, 'name': 'Documentary'}]  224332.0
# 2   5000000.0                      [{'id': 18, 'name': 'Drama'}]  567662.0
# 3  65000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...  116977.0
# 4   2000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  323498.0
#
#      imdb_id release_date  revenue                               title  \
# 0  tt0069049   2018-11-02      0.0          The Other Side of the Wind
# 1  tt0159369   2013-09-27      0.0  Cooper and Hemingway: The True Gen
# 2  tt0192528   2018-11-06      0.0                       Heaven & Hell
# 3  tt0249516   2012-06-15  73706.0                          Foodfight!
# 4  tt0255820   2013-08-11      0.0                   Return to Babylon
#
#                                              results  month  year
# 0  [{'iso_3166_1': 'US', 'release_dates': [{'cert...     11  2018
# 1  [{'iso_3166_1': 'US', 'release_dates': [{'cert...      9  2013
# 2  [{'iso_3166_1': 'US', 'release_dates': [{'cert...     11  2018
# 3  [{'iso_3166_1': 'US', 'release_dates': [{'cert...      6  2012
# 4  [{'iso_3166_1': 'US', 'release_dates': [{'cert...      8  2013

# %%
#pulls out just the genre names and puts them into a single list
for x in range(len(movie_data.genres)):
    movie_data.genres[x] = [y['name'] for y in movie_data.genres[x]]
# Out:
# /Users/danielmocombe/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#function that will get the value for certification key which is a nested list of dictionaries under results column
def get_cert(test):
    for x in range(len(test)):
        for y in test[x].keys():
            while test[x][y] == 'US':
                return test[x]['release_dates'][0]['certification']
            continue

# %%
#function that shows the name of the seasion for each month based on Box Office Mojo's categorization
def season(x):
    if x >= 1 and x <= 2:
        return 'Winter'
    elif x >= 3 and x <= 4:
        return 'Spring'
    elif x >= 5 and x <= 8:
        return 'Summer'
    elif x >= 9 and x <= 10:
        return 'Fall' 
    else:
        return 'Holiday'

# %%
#create new column that applies get_cert function to the df
movie_data['rating'] = movie_data.results.apply(get_cert)
#create new column that applies season function to the df
movie_data['season'] = movie_data.month.apply(season)
#create column that just shows first genre from genres list
movie_data['genre'] = movie_data['genres'].str[0]
#create column that calculates the profitability per movie
movie_data['profitability'] = movie_data['revenue'] - movie_data['budget']

# %%
#remove null rating values
clean_movie_data = movie_data.dropna(subset=['rating'])

#remove movies with 0 budgets
clean_movie_data = clean_movie_data.loc[~(clean_movie_data['budget'] == 0)]

#remove null genre values
clean_movie_data = clean_movie_data.dropna(subset=['rating'])

# %%
#sort results by revenue
clean_movie_data = clean_movie_data.sort_values(by=['revenue'], ascending=[False])
clean_movie_data.head(10)
# Out:
#             budget                                          genres        id  \
# 15167  356000000.0            [Adventure, Science Fiction, Action]  299534.0
# 9384   245000000.0   [Action, Adventure, Science Fiction, Fantasy]  140607.0
# 15166  300000000.0            [Adventure, Action, Science Fiction]  299536.0
# 18     150000000.0  [Action, Adventure, Science Fiction, Thriller]  135397.0
# 19625  260000000.0                             [Adventure, Family]  420818.0
# 210    220000000.0            [Science Fiction, Action, Adventure]   24428.0
# 10542  190000000.0                              [Action, Thriller]  168259.0
# 8842   250000000.0            [Action, Adventure, Science Fiction]   99861.0
# 4647   200000000.0   [Action, Adventure, Fantasy, Science Fiction]  284054.0
# 662    125000000.0                            [Fantasy, Adventure]   12445.0
#
#          imdb_id release_date       revenue  \
# 15167  tt4154796   2019-04-24  2.797801e+09
# 9384   tt2488496   2015-12-15  2.068224e+09
# 15166  tt4154756   2018-04-25  2.046240e+09
# 18     tt0369610   2015-06-06  1.671713e+09
# 19625  tt6105098   2019-07-12  1.656943e+09
# 210    tt0848228   2012-04-25  1.519558e+09
# 10542  tt2820852   2015-04-01  1.515048e+09
# 8842   tt2395427   2015-04-22  1.405404e+09
# 4647   tt1825683   2018-02-13  1.346739e+09
# 662    tt1201607   2011-07-07  1.341511e+09
#
#                                               title  \
# 15167                             Avengers: Endgame
# 9384                   Star Wars: The Force Awakens
# 15166                        Avengers: Infinity War
# 18                                   Jurassic World
# 19625                                 The Lion King
# 210                                    The Avengers
# 10542                                     Furious 7
# 8842                        Avengers: Age of Ultron
# 4647                                  Black Panther
# 662    Harry Potter and the Deathly Hallows: Part 2
#
#                                                  results  month  year rating  \
# 15167  [{'iso_3166_1': 'IT', 'release_dates': [{'cert...      4  2019  PG-13
# 9384   [{'iso_3166_1': 'IT', 'release_dates': [{'cert...     12  2015
# 15166  [{'iso_3166_1': 'US', 'release_dates': [{'cert...      4  2018  PG-13
# 18     [{'iso_3166_1': 'GR', 'release_dates': [{'cert...      6  2015  PG-13
# 19625  [{'iso_3166_1': 'KR', 'release_dates': [{'cert...      7  2019     PG
# 210    [{'iso_3166_1': 'GR', 'release_dates': [{'cert...      4  2012  PG-13
# 10542  [{'iso_3166_1': 'US', 'release_dates': [{'cert...      4  2015  PG-13
# 8842   [{'iso_3166_1': 'US', 'release_dates': [{'cert...      4  2015  PG-13
# 4647   [{'iso_3166_1': 'US', 'release_dates': [{'cert...      2  2018  PG-13
# 662    [{'iso_3166_1': 'KR', 'release_dates': [{'cert...      7  2011  PG-13
#
#         season            genre  profitability
# 15167   Spring        Adventure   2.441801e+09
# 9384   Holiday           Action   1.823224e+09
# 15166   Spring        Adventure   1.746240e+09
# 18      Summer           Action   1.521713e+09
# 19625   Summer        Adventure   1.396943e+09
# 210     Spring  Science Fiction   1.299558e+09
# 10542   Spring           Action   1.325048e+09
# 8842    Spring           Action   1.155404e+09
# 4647    Winter           Action   1.146739e+09
# 662     Summer          Fantasy   1.216511e+09

# %%
#drop any remaining columns we don't need for analysis

clean_movie_data = clean_movie_data.drop(columns = ['genres', 'results', 'id'])

#only keep rows that have an mpaa rating
clean_movie_data = clean_movie_data[clean_movie_data['rating'].isin(['G', 'PG', 'PG-13', 'R'])]

# %%
clean_movie_data.head(50)
# Out:
#             budget    imdb_id release_date       revenue  \
# 15167  356000000.0  tt4154796   2019-04-24  2.797801e+09
# 15166  300000000.0  tt4154756   2018-04-25  2.046240e+09
# 18     150000000.0  tt0369610   2015-06-06  1.671713e+09
# 19625  260000000.0  tt6105098   2019-07-12  1.656943e+09
# 210    220000000.0  tt0848228   2012-04-25  1.519558e+09
# 10542  190000000.0  tt2820852   2015-04-01  1.515048e+09
# 8842   250000000.0  tt2395427   2015-04-22  1.405404e+09
# 4647   200000000.0  tt1825683   2018-02-13  1.346739e+09
# 662    125000000.0  tt1201607   2011-07-07  1.341511e+09
# 9554   200000000.0  tt2527336   2017-12-13  1.332540e+09
# 16130  150000000.0  tt4520988   2019-11-20  1.330765e+09
# 7955   150000000.0  tt2294629   2013-11-27  1.274219e+09
# 10381  160000000.0  tt2771200   2017-03-16  1.263521e+09
# 13486  200000000.0  tt3606756   2018-06-14  1.242805e+09
# 16364  250000000.0  tt4630562   2017-04-12  1.238765e+09
# 1018   200000000.0  tt1300854   2013-04-18  1.214811e+09
# 7948    74000000.0  tt2293640   2015-06-17  1.156731e+09
# 13035  250000000.0  tt3498820   2016-04-27  1.153296e+09
# 20100  160000000.0  tt6320628   2019-06-28  1.131928e+09
# 15165  152000000.0  tt4154664   2019-03-06  1.128275e+09
# 1429   195000000.0  tt1399103   2011-06-28  1.123794e+09
# 466    200000000.0  tt1074638   2012-10-25  1.108561e+09
# 6670   210000000.0  tt2109248   2014-06-25  1.104054e+09
# 1260   250000000.0  tt1345836   2012-07-16  1.081041e+09
# 21473   55000000.0  tt7286456   2019-10-02  1.074251e+09
# 9555   250000000.0  tt2527338   2019-12-18  1.074144e+09
# 5695   175000000.0  tt1979376   2019-06-19  1.073395e+09
# 43     200000000.0  tt0435761   2010-06-16  1.066970e+09
# 13980  200000000.0  tt3748528   2016-12-14  1.056057e+09
# 19691  183000000.0  tt6139732   2019-05-22  1.047612e+09
# 1016   380000000.0  tt1298650   2011-05-14  1.045714e+09
# 12934   80000000.0  tt3469046   2017-06-15  1.031553e+09
# 7829   200000000.0  tt2277860   2016-06-16  1.028571e+09
# 354    200000000.0  tt1014759   2010-03-03  1.025467e+09
# 10925  150000000.0  tt2948356   2016-02-11  1.023784e+09
# 256    250000000.0  tt0903624   2012-11-26  1.021104e+09
# 3447    76000000.0  tt1690953   2013-06-25  9.707619e+08
# 11236  175000000.0  tt3040964   2016-04-07  9.665506e+08
# 7885    90000000.0  tt2283362   2017-12-09  9.621022e+08
# 599    250000000.0  tt1170358   2013-12-11  9.584000e+08
# 8069   250000000.0  tt2310332   2014-12-10  9.560198e+08
# 268    250000000.0  tt0926084   2010-10-17  9.543059e+08
# 3789    52000000.0  tt1727824   2018-10-24  8.940275e+08
# 8663   245000000.0  tt2379713   2015-10-26  8.806746e+08
# 7627   175000000.0  tt2250912   2017-07-05  8.801669e+08
# 3257    95000000.0  tt1667889   2012-06-26  8.772448e+08
# 10181   75000000.0  tt2709768   2016-06-18  8.754579e+08
# 11026  250000000.0  tt2975590   2016-03-23  8.736349e+08
# 14449  200000000.0  tt3896198   2017-04-19  8.637561e+08
# 6570   175000000.0  tt2096673   2015-06-09  8.576112e+08
#
#                                               title  month  year rating  \
# 15167                             Avengers: Endgame      4  2019  PG-13
# 15166                        Avengers: Infinity War      4  2018  PG-13
# 18                                   Jurassic World      6  2015  PG-13
# 19625                                 The Lion King      7  2019     PG
# 210                                    The Avengers      4  2012  PG-13
# 10542                                     Furious 7      4  2015  PG-13
# 8842                        Avengers: Age of Ultron      4  2015  PG-13
# 4647                                  Black Panther      2  2018  PG-13
# 662    Harry Potter and the Deathly Hallows: Part 2      7  2011  PG-13
# 9554                       Star Wars: The Last Jedi     12  2017  PG-13
# 16130                                     Frozen II     11  2019     PG
# 7955                                         Frozen     11  2013     PG
# 10381                          Beauty and the Beast      3  2017     PG
# 13486                                 Incredibles 2      6  2018     PG
# 16364                       The Fate of the Furious      4  2017  PG-13
# 1018                                     Iron Man 3      4  2013  PG-13
# 7948                                        Minions      6  2015     PG
# 13035                    Captain America: Civil War      4  2016  PG-13
# 20100                     Spider-Man: Far from Home      6  2019  PG-13
# 15165                                Captain Marvel      3  2019  PG-13
# 1429                 Transformers: Dark of the Moon      6  2011  PG-13
# 466                                         Skyfall     10  2012  PG-13
# 6670                Transformers: Age of Extinction      6  2014  PG-13
# 1260                          The Dark Knight Rises      7  2012  PG-13
# 21473                                         Joker     10  2019      R
# 9555               Star Wars: The Rise of Skywalker     12  2019  PG-13
# 5695                                    Toy Story 4      6  2019      G
# 43                                      Toy Story 3      6  2010      G
# 13980                  Rogue One: A Star Wars Story     12  2016  PG-13
# 19691                                       Aladdin      5  2019     PG
# 1016    Pirates of the Caribbean: On Stranger Tides      5  2011  PG-13
# 12934                               Despicable Me 3      6  2017     PG
# 7829                                   Finding Dory      6  2016     PG
# 354                             Alice in Wonderland      3  2010     PG
# 10925                                      Zootopia      2  2016     PG
# 256               The Hobbit: An Unexpected Journey     11  2012  PG-13
# 3447                                Despicable Me 2      6  2013     PG
# 11236                               The Jungle Book      4  2016     PG
# 7885                 Jumanji: Welcome to the Jungle     12  2017  PG-13
# 599             The Hobbit: The Desolation of Smaug     12  2013  PG-13
# 8069      The Hobbit: The Battle of the Five Armies     12  2014  PG-13
# 268    Harry Potter and the Deathly Hallows: Part 1     10  2010  PG-13
# 3789                              Bohemian Rhapsody     10  2018  PG-13
# 8663                                        Spectre     10  2015  PG-13
# 7627                         Spider-Man: Homecoming      7  2017  PG-13
# 3257                     Ice Age: Continental Drift      6  2012     PG
# 10181                       The Secret Life of Pets      6  2016     PG
# 11026            Batman v Superman: Dawn of Justice      3  2016  PG-13
# 14449                Guardians of the Galaxy Vol. 2      4  2017  PG-13
# 6570                                     Inside Out      6  2015     PG
#
#         season            genre  profitability
# 15167   Spring        Adventure   2.441801e+09
# 15166   Spring        Adventure   1.746240e+09
# 18      Summer           Action   1.521713e+09
# 19625   Summer        Adventure   1.396943e+09
# 210     Spring  Science Fiction   1.299558e+09
# 10542   Spring           Action   1.325048e+09
# 8842    Spring           Action   1.155404e+09
# 4647    Winter           Action   1.146739e+09
# 662     Summer          Fantasy   1.216511e+09
# 9554   Holiday  Science Fiction   1.132540e+09
# 16130  Holiday        Animation   1.180765e+09
# 7955   Holiday        Animation   1.124219e+09
# 10381   Spring           Family   1.103521e+09
# 13486   Summer           Action   1.042805e+09
# 16364   Spring           Action   9.887648e+08
# 1018    Spring           Action   1.014811e+09
# 7948    Summer           Family   1.082731e+09
# 13035   Spring        Adventure   9.032963e+08
# 20100   Summer           Action   9.719280e+08
# 15165   Spring           Action   9.762748e+08
# 1429    Summer           Action   9.287941e+08
# 466       Fall           Action   9.085610e+08
# 6670    Summer  Science Fiction   8.940541e+08
# 1260    Summer           Action   8.310413e+08
# 21473     Fall            Crime   1.019251e+09
# 9555   Holiday           Action   8.241442e+08
# 5695    Summer        Adventure   8.983946e+08
# 43      Summer        Animation   8.669697e+08
# 13980  Holiday           Action   8.560573e+08
# 19691   Summer        Adventure   8.646124e+08
# 1016    Summer        Adventure   6.657138e+08
# 12934   Summer           Action   9.515526e+08
# 7829    Summer        Adventure   8.285709e+08
# 354     Spring           Family   8.254671e+08
# 10925   Winter        Animation   8.737842e+08
# 256    Holiday        Adventure   7.711036e+08
# 3447    Summer        Animation   8.947619e+08
# 11236   Spring        Adventure   7.915506e+08
# 7885   Holiday           Action   8.721022e+08
# 599    Holiday        Adventure   7.084000e+08
# 8069   Holiday           Action   7.060198e+08
# 268       Fall        Adventure   7.043059e+08
# 3789      Fall            Drama   8.420275e+08
# 8663      Fall           Action   6.356746e+08
# 7627    Summer           Action   7.051669e+08
# 3257    Summer        Animation   7.822448e+08
# 10181   Summer        Adventure   8.004579e+08
# 11026   Spring           Action   6.236349e+08
# 14449   Spring           Action   6.637561e+08
# 6570    Summer            Drama   6.826112e+08

# %%
clean_movie_data.to_csv('clean_movie_data.csv', index = False)

# %% [markdown]
# # Movie Actor Data
#
# - Merge IMDB dataframes related to movie actos
# - Specify actors in movies released in the US
# - Drop unnecessary columns and duplicate values
# - Merge cleaned dataframe with movie_data

# %%
#joined these tables to get the name and the specific profession ('category') they had for that movie

name_p = imdb_name.merge(imdb_title_p, on = 'nconst', how = 'left') 
name_p.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0061865       Joseph Bauer         NaN         NaN
# 3  nm0061865       Joseph Bauer         NaN         NaN
# 4  nm0061865       Joseph Bauer         NaN         NaN
#
#                            primary_profession  \
# 0   miscellaneous,production_manager,producer
# 1  composer,music_department,sound_department
# 2  composer,music_department,sound_department
# 3  composer,music_department,sound_department
# 4  composer,music_department,sound_department
#
#                           known_for_titles     tconst  ordering  category  \
# 0  tt0837562,tt2398241,tt0844471,tt0118553  tt2398241       9.0  producer
# 1  tt0896534,tt6791238,tt0287072,tt1682940  tt0433397       7.0  composer
# 2  tt0896534,tt6791238,tt0287072,tt1682940  tt1681372       8.0  composer
# 3  tt0896534,tt6791238,tt0287072,tt1682940  tt2387710       8.0  composer
# 4  tt0896534,tt6791238,tt0287072,tt1682940  tt2281215       7.0  composer
#
#         job characters
# 0  producer        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN

# %%
#renamed the 'tconst' column to match the title_id column and use that later to join with title_ba table
name_p = name_p.rename(columns = {"tconst": "title_id", "nconst": "name_id"})

# %%
#joined both tables to get the name and the title info together
name_titles = title_ba.merge(name_p, on = 'title_id', how = 'left')
name_titles.head()
# Out:
#     title_id primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 1  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 2  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 3  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 4  tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                genres  ordering_x      title region language  ...    name_id  \
# 0  Action,Crime,Drama         1.0  Sangharsh     IN       hi  ...  nm0347899
# 1  Action,Crime,Drama         1.0  Sangharsh     IN       hi  ...  nm1194313
# 2  Action,Crime,Drama         1.0  Sangharsh     IN       hi  ...  nm0712540
# 3  Action,Crime,Drama         1.0  Sangharsh     IN       hi  ...  nm0904537
# 4  Action,Crime,Drama         1.0  Sangharsh     IN       hi  ...  nm0023551
#
#           primary_name  birth_year death_year  \
# 0               Gulzar      1936.0        NaN
# 1       Mahasweta Devi      1926.0     2016.0
# 2  Harnam Singh Rawail      1921.0     2004.0
# 3       Vyjayanthimala      1933.0        NaN
# 4           Abrar Alvi      1927.0     2009.0
#
#                        primary_profession  \
# 0      music_department,writer,soundtrack
# 1                                  writer
# 2                director,writer,producer
# 3  actress,music_department,miscellaneous
# 4                   writer,actor,director
#
#                           known_for_titles  ordering_y  category       job  \
# 0  tt0091256,tt0178186,tt1010048,tt2176013         8.0    writer  dialogue
# 1  tt0108001,tt0832902,tt0063540,tt0178562         7.0    writer     story
# 2  tt0266757,tt0266712,tt0134996,tt0266765         5.0  director       NaN
# 3  tt0047990,tt0054910,tt0050665,tt0058547         2.0   actress       NaN
# 4  tt0071811,tt0359496,tt0056436,tt0061046         6.0    writer  dialogue
#
#                     characters
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3  ["Munni","Laila-E-Aasmaan"]
# 4                          NaN
#
# [5 rows x 23 columns]

# %%
#grouped by region and used get group to only show the US movies
us_name_titles = name_titles.groupby('region').get_group('US')
us_name_titles.head()
# Out:
#       title_id               primary_title              original_title  \
# 128  tt0069049  The Other Side of the Wind  The Other Side of the Wind
# 129  tt0069049  The Other Side of the Wind  The Other Side of the Wind
# 130  tt0069049  The Other Side of the Wind  The Other Side of the Wind
# 131  tt0069049  The Other Side of the Wind  The Other Side of the Wind
# 132  tt0069049  The Other Side of the Wind  The Other Side of the Wind
#
#      start_year  runtime_minutes genres  ordering_x  \
# 128        2018            122.0  Drama         2.0
# 129        2018            122.0  Drama         2.0
# 130        2018            122.0  Drama         2.0
# 131        2018            122.0  Drama         2.0
# 132        2018            122.0  Drama         2.0
#
#                           title region language  ...    name_id  \
# 128  The Other Side of the Wind     US      NaN  ...  nm0006166
# 129  The Other Side of the Wind     US      NaN  ...  nm0462648
# 130  The Other Side of the Wind     US      NaN  ...  nm0004372
# 131  The Other Side of the Wind     US      NaN  ...  nm0001379
# 132  The Other Side of the Wind     US      NaN  ...  nm0613657
#
#        primary_name  birth_year death_year  \
# 128  Michel Legrand      1932.0     2019.0
# 129       Oja Kodar      1941.0        NaN
# 130     Gary Graver      1938.0     2006.0
# 131     John Huston      1906.0     1987.0
# 132    Bob Murawski      1964.0        NaN
#
#                              primary_profession  \
# 128        composer,soundtrack,music_department
# 129                     actress,writer,director
# 130  cinematographer,director,camera_department
# 131                       actor,director,writer
# 132        editor,producer,editorial_department
#
#                             known_for_titles  ordering_y         category  \
# 128  tt0067334,tt0067803,tt0086619,tt0063688         8.0         composer
# 129  tt0069049,tt0108506,tt0209994,tt0239070         2.0          actress
# 130  tt0178845,tt0121549,tt0207568,tt0082004         9.0  cinematographer
# 131  tt0040897,tt0040506,tt0071315,tt0043265         1.0            actor
# 132  tt0887912,tt0316654,tt0145487,tt0069049        10.0           editor
#
#      job          characters
# 128  NaN                 NaN
# 129  NaN     ["The Actress"]
# 130  NaN                 NaN
# 131  NaN  ["Jake Hannaford"]
# 132  NaN                 NaN
#
# [5 rows x 23 columns]

# %%
#check columns
us_name_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 388927 entries, 128 to 2975188
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   title_id            388927 non-null  object
#  1   primary_title       388927 non-null  object
#  2   original_title      388926 non-null  object
#  3   start_year          388927 non-null  int64
#  4   runtime_minutes     331117 non-null  float64
#  5   genres              385776 non-null  object
#  6   ordering_x          388927 non-null  float64
#  7   title               388927 non-null  object
#  8   region              388927 non-null  object
#  9   language            5128 non-null    object
#  10  types               62174 non-null   object
#  11  attributes          22294 non-null   object
#  12  is_original_title   388922 non-null  float64
#  13  name_id             388634 non-null  object
#  14  primary_name        388634 non-null  object
#  15  birth_year          100819 non-null  float64
#  16  death_year          4871 non-null    float64
#  17  primary_profession  369204 non-null  object
#  18  known_for_titles    386256 non-null  object
#  19  ordering_y          388634 non-null  float64
#  20  category            388634 non-null  object
#  21  job                 75453 non-null   object
#  22  characters          173140 non-null  object
# dtypes: float64(6), int64(1), object(16)
# memory usage: 71.2+ MB

# %%
#drop irrelevant colunms
clean_us_names = us_name_titles.drop(columns = ['primary_title', 'original_title', 'start_year', 'language', 'types', 'attributes', 'is_original_title', 'birth_year', 'death_year', 'genres', 'ordering_x', 'ordering_y', 'primary_profession', 'known_for_titles', 'job'])
clean_us_names.head()
# Out:
#       title_id  runtime_minutes                       title region    name_id  \
# 128  tt0069049            122.0  The Other Side of the Wind     US  nm0006166
# 129  tt0069049            122.0  The Other Side of the Wind     US  nm0462648
# 130  tt0069049            122.0  The Other Side of the Wind     US  nm0004372
# 131  tt0069049            122.0  The Other Side of the Wind     US  nm0001379
# 132  tt0069049            122.0  The Other Side of the Wind     US  nm0613657
#
#        primary_name         category          characters
# 128  Michel Legrand         composer                 NaN
# 129       Oja Kodar          actress     ["The Actress"]
# 130     Gary Graver  cinematographer                 NaN
# 131     John Huston            actor  ["Jake Hannaford"]
# 132    Bob Murawski           editor                 NaN

# %%
#filter to just get actor and actress names per movie
clean_us_actors = clean_us_names[clean_us_names['category'].isin(['actor', 'actress'])]

#drop any duplicates that have the same title_id and name_id
clean_us_actors = clean_us_actors.drop_duplicates(subset=(['title_id', 'name_id']), keep="first")

# %%
#rename columns to match up with movie_data for merging
clean_us_actors = clean_us_actors.rename(columns = {"title_id": "imdb_id", "primary_name": "name"})
clean_us_actors.head()
# Out:
#        imdb_id  runtime_minutes                               title region  \
# 129  tt0069049            122.0          The Other Side of the Wind     US
# 131  tt0069049            122.0          The Other Side of the Wind     US
# 133  tt0069049            122.0          The Other Side of the Wind     US
# 136  tt0069049            122.0          The Other Side of the Wind     US
# 488  tt0159369            180.0  Cooper and Hemingway: The True Gen     US
#
#        name_id               name category             characters
# 129  nm0462648          Oja Kodar  actress        ["The Actress"]
# 131  nm0001379        John Huston    actor     ["Jake Hannaford"]
# 133  nm0000953  Peter Bogdanovich    actor   ["Brooks Otterlake"]
# 136  nm0001782    Susan Strasberg  actress         ["Julie Rich"]
# 488  nm0186908     Nancy Crawford  actress  ["Additional voices"]

# %%
#merge movie_data with clean_us_actors on imdb_id column
movie_actor = clean_movie_data.merge(clean_us_actors, on = 'imdb_id', how = 'left')

# %%
#drop any remaining columns we don't need for analysis
movie_actor = movie_actor.drop(columns = ['runtime_minutes', 'title_y', 'region', 'imdb_id', 'name_id'])

# %%
#rename title
movie_actor = movie_actor.rename(columns = {"title_x":"title"})

# %%
movie_actor.head()
# Out:
#         budget release_date       revenue                   title  month  \
# 0  356000000.0   2019-04-24  2.797801e+09       Avengers: Endgame      4
# 1  356000000.0   2019-04-24  2.797801e+09       Avengers: Endgame      4
# 2  356000000.0   2019-04-24  2.797801e+09       Avengers: Endgame      4
# 3  356000000.0   2019-04-24  2.797801e+09       Avengers: Endgame      4
# 4  300000000.0   2018-04-25  2.046240e+09  Avengers: Infinity War      4
#
#    year rating  season      genre  profitability               name category  \
# 0  2019  PG-13  Spring  Adventure   2.441801e+09       Mark Ruffalo    actor
# 1  2019  PG-13  Spring  Adventure   2.441801e+09    Chris Hemsworth    actor
# 2  2019  PG-13  Spring  Adventure   2.441801e+09        Chris Evans    actor
# 3  2019  PG-13  Spring  Adventure   2.441801e+09  Robert Downey Jr.    actor
# 4  2018  PG-13  Spring  Adventure   1.746240e+09       Mark Ruffalo    actor
#
#                            characters
# 0             ["Bruce Banner","Hulk"]
# 1                            ["Thor"]
# 2  ["Steve Rogers","Captain America"]
# 3           ["Tony Stark","Iron Man"]
# 4             ["Bruce Banner","Hulk"]

# %%
movie_actor.to_csv('movie_actor.csv', index = False)

# %% [markdown]
# ### Additional Steps taken before visualization
#
# - below are the lines of code needed to get the correct dataframe for visualization
# - broadly, we needed to drop additional columns, add a profitibility column, adjust the float format, and create a few variables

# %%
movies_df = pd.read_csv('movies_data.csv')

# %%
month_movies_df = movies_df.sort_values(by=['month'], ascending=[True])
month_movies_df

# %%
test_df = movies_df.drop(columns=['genre_7', 'genre_6', 'genre_5', 'genre_4', 'genre_3', 'genre_2'])
test_df = test_df.sort_values(by=['revenue'], ascending=[False])
rating_test_df = test_df.dropna(subset=['rating'])
rating_test_df

# %%
clean_rating_df = rating_test_df[rating_test_df['rating'].isin(['G', 'PG', 'PG-13', 'R'])]

# %%
clean_rating_df['profitability'] = clean_rating_df['revenue'] - clean_rating_df['budget']

# %%
clean_budget_df = clean_rating_df.loc[~(clean_rating_df['budget'] == 0)]
clean_genre_df = clean_budget_df.dropna(subset=['genre_1'])
clean_genre_df

# %%
corr = clean_budget_df.corr()

# %%
clean_genre_df.groupby('genre_1')['profitability'].mean()

# %%
pd.options.display.float_format = "{:.2f}".format

clean_genre_df.describe()

# %%
clean_genre_df.head()

# %%
last_ten_years = clean_genre_df.loc[clean_genre_df['year']>=2010]
last_ten_years

# %%
movies_by_revenue = last_ten_years['revenue'].mean()
movies_by_revenue

# %%
clean_genre_df.to_csv('clean_movie_data_final.csv')
